# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Censes 2011.csv')

# %%
df
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %% [markdown]
# Import the dataset into a Pandas DataFrame and perform exploratory data analysis to understand the distribution of the different variables.

# %%
df.describe()
# Out:
#        District code    Population          Male        Female      Literate  \
# count     640.000000  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean      320.500000  1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06
# std       184.896367  1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05
# 50%       320.500000  1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05
# 75%       480.250000  2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06
# max       640.000000  1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#        Male_Literate  Female_Literate       Workers  Male_Workers  \
# count   6.400000e+02     6.400000e+02  6.400000e+02  6.400000e+02
# mean    6.793182e+05     5.138675e+05  7.529514e+05  5.186561e+05
# std     5.924144e+05     4.801816e+05  6.071622e+05  4.412388e+05
# ...

# %% [markdown]
# For different states find out the mean total Population.

# %%
df.columns
# Out:
# Index(['District code', 'State name', 'District name', 'Population', 'Male',
#        'Female', 'Literate', 'Male_Literate', 'Female_Literate', 'Workers',
#        'Male_Workers', 'Female_Workers', 'Main_Workers', 'Marginal_Workers',
#        'Non_Workers', 'Cultivator_Workers', 'Agricultural_Workers',
#        'Household_Workers', 'Other_Workers', 'Hindus', 'Muslims', 'Christians',
#        'Sikhs', 'Buddhists', 'Jains', 'Others_Religions',
#        'Religion_Not_Stated'],
#       dtype='object')

# %%
df.groupby("State name")['Population'].mean().to_frame()
# Out:
#                                Population
# State name
# ANDAMAN AND NICOBAR ISLANDS  1.268603e+05
# ANDHRA PRADESH               3.677425e+06
# ARUNACHAL PRADESH            8.648294e+04
# ASSAM                        1.155762e+06
# BIHAR                        2.739459e+06
# CHANDIGARH                   1.055450e+06
# CHHATTISGARH                 1.419178e+06
# DADRA AND NAGAR HAVELI       3.437090e+05
# DAMAN AND DIU                1.216235e+05
# GOA                          7.292725e+05
# GUJARAT                      2.324604e+06
# HARYANA                      1.207212e+06
# HIMACHAL PRADESH             5.720502e+05
# JAMMU AND KASHMIR            5.700592e+05
# JHARKHAND                    1.374506e+06
# KARNATAKA                    2.036510e+06
# KERALA                       2.386147e+06
# LAKSHADWEEP                  6.447300e+04
# MADHYA PRADESH               1.452536e+06
# MAHARASHTRA                  3.210695e+06
# MANIPUR                      3.173104e+05
# ...

# %% [markdown]
# Calculate the mean, median, and standard deviation of the different variables like “Male_Literate”,”Female_Workers”, “Population”. etc.

# %%
df.describe()[['Male_Literate','Female_Workers', 'Population']].loc[['mean','std','50%']]
# Out:
#       Male_Literate  Female_Workers    Population
# mean  679318.159375   234295.301563  1.891961e+06
# std   592414.360959   191354.104363  1.544380e+06
# 50%   548352.500000   192926.500000  1.557367e+06

# %% [markdown]
# Use the 65-95-99 rule to identify the outliers in the population column.

# %%
m=df['Population'].mean()
s=df['Population'].std()

df['Population']<=m-3*s
df['Population']>=m+3*s
df[(df['Population']<=m-3*s)|(df['Population']>=m+3*s)].shape[0]
# Out:
# 10

# %% [markdown]
# Check how many observations lie within 3 standard deviations for each column.

# %%
m=df.mean()
s=df.std()
((df>=m-3*s)&(df<=m+3*s)).sum()
# Out:
# <ipython-input-39-1824d19de959>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   m=df.mean()
# <ipython-input-39-1824d19de959>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   s=df.std()
# <ipython-input-39-1824d19de959>:3: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   ((df>=m-3*s)&(df<=m+3*s)).sum()
# Agricultural_Workers    628
# Buddhists               627
# Christians              625
# Cultivator_Workers      631
# District code           640
# ...

# %% [markdown]
# Plot the density distribution for different variables. Do this for at least 3 columns.

# %%
df['Female_Workers'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['Female'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['Female_Literate'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
